# %% [markdown]
# <a href="https://colab.research.google.com/github/RayenBoukhchina/Music-Reccomandation-System/blob/main/Music_Reccomandation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('musics.csv')

# %%
data
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2420 entries, 0 to 2419
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Song-Name       2420 non-null   object
#  1   Singer/Artists  2410 non-null   object
#  2   Genre           2420 non-null   object
#  3   Album/Movie     2417 non-null   object
#  4   User-Rating     2420 non-null   object
# dtypes: object(5)
# memory usage: 94.7+ KB

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Song-Name         0
# Singer/Artists    0
# Genre             0
# Album/Movie       0
# User-Rating       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2407 entries, 0 to 2419
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Song-Name       2407 non-null   object
#  1   Singer/Artists  2407 non-null   object
#  2   Genre           2407 non-null   object
#  3   Album/Movie     2407 non-null   object
#  4   User-Rating     2407 non-null   object
# dtypes: object(5)
# memory usage: 112.8+ KB

# %%
data.duplicated().sum()
# Out:
# 16

# %%
data=data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#          Song-Name Singer/Artists           Genre      Album/Movie User-Rating
# count         2391           2391            2391             2391        2391
# unique        2327           1214              20              900          40
# top     Tere Naina  Mohammed Rafi  BollywoodDance  Bajirao Mastani      9.4/10
# freq             3             55            1210               10         274

# %%
data
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# ...

# %%
l=[]
for i in data['User-Rating']:
  l.append(i[:3])
l
# Out:
# ['8.8',
#  '9.0',
#  '9.7',
#  '9.1',
#  '9.2',
#  '9.1',
#  '9.2',
#  '9.5',
#  '9.2',
#  '9.6',
#  '8.8',
#  '8.4',
#  '9.1',
#  '9.2',
#  '9.0',
#  '9.7',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.1',
#  '9.2',
#  '9.2',
#  '9.5',
#  '8.6',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.2',
#  '9.5',
#  '9.4',
#  '8.7',
#  '9.3',
#  '9.3',
#  '9.5',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.1',
#  '8.4',
#  '8.4',
#  '8.8',
#  '9.2',
#  '9.2',
#  '9.6',
#  '9.6',
#  '9.0',
#  '9.1',
#  '8.5',
#  '9.5',
#  '8.5',
#  '9.7',
#  '8.9',
#  '9.6',
#  '8.5',
#  '9.1',
#  '8.7',
#  '8.6',
#  '9.3',
#  '9.7',
#  '8.9',
#  '9.0',
#  '9.0',
#  '9.3',
#  '9.3',
#  '9.1',
#  '9.0',
#  '9.7',
#  '9.2',
#  '9.1',
#  '9.0',
#  '8.9',
#  '9.5',
#  '9.5',
#  '9.7',
#  '9.0',
#  '8.1',
#  '8.1',
#  '9.5',
#  '9.1',
#  '8.6',
#  '9.4',
#  '9.0',
#  '9.0',
#  '9.6',
#  '9.3',
#  '9.0',
#  '9.2',
#  '9.3',
#  '9.1',
#  '8.6',
#  '9.5',
#  '9.5',
#  '9.0',
#  '9.4',
#  '9.2',
#  '9.6',
#  '9.3',
#  '7.7',
#  '9.2',
#  '9.3',
# ...

# %%
data['User-Rating']=l
data
# Out:
# <ipython-input-14-b1541f4d6ab7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['User-Rating']=l
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2391 entries, 0 to 2419
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Song-Name       2391 non-null   object
#  1   Singer/Artists  2391 non-null   object
#  2   Genre           2391 non-null   object
#  3   Album/Movie     2391 non-null   object
#  4   User-Rating     2391 non-null   object
# dtypes: object(5)
# memory usage: 112.1+ KB

# %%
data['Album/Movie']=data['Album/Movie'].str.replace(' ','')
data['Singer/Artists']=data['Singer/Artists'].str.replace(' ','')
# Out:
# <ipython-input-16-bea10ad46ee1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Album/Movie']=data['Album/Movie'].str.replace(' ','')
# <ipython-input-16-bea10ad46ee1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Singer/Artists']=data['Singer/Artists'].str.replace(' ','')

# %%
data['Singer/Artists']=data['Singer/Artists'].str.replace(',',' ')
# Out:
# <ipython-input-17-4583c614f266>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Singer/Artists']=data['Singer/Artists'].str.replace(',',' ')

# %%
data['tags']=data['Album/Movie']+' '+data['Singer/Artists']+' '+data['Genre']+' '+data['User-Rating']
# Out:
# <ipython-input-18-d2f709fe1da2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['tags']=data['Album/Movie']+' '+data['Singer/Artists']+' '+data['Genre']+' '+data['User-Rating']

# %%
data
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                  Singer/Artists                   Genre  \
# 0                KumarSanu MikaSingh NehaKakkar          BollywoodDance
# 1                         NehaKakkar TonyKakkar  BollywoodDanceRomantic
# 2                                  RanveerSingh          BollywoodDance
# 3             JyoticaTangri Shaan SubhroGanguly          BollywoodDance
# 4     AseesKaur RahatFatehAliKhan TanishkBagchi       BollywoodRomantic
# ...

# %%
df=data[['Song-Name','tags']]
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# 0     Simmba KumarSanu MikaSingh NehaKakkar Bollywoo...
# 1     LukaChuppi NehaKakkar TonyKakkar BollywoodDanc...
# 2              GullyBoy RanveerSingh BollywoodDance 9.7
# 3     TotalDhamaal JyoticaTangri Shaan SubhroGanguly...
# 4     Simmba AseesKaur RahatFatehAliKhan TanishkBagc...
# ...                                                 ...
# 2415                  Sasural Mukesh BollywoodDance 6.2
# ...

# %%
df['tags']=df['tags'].apply(lambda x:x.lower())
# Out:
# <ipython-input-21-285b77110f41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags']=df['tags'].apply(lambda x:x.lower())

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=2000,stop_words='english')

# %%
vectors=cv.fit_transform(df['tags']).toarray()

# %%
vectors.shape
# Out:
# (2391, 1695)

# %%
cv.get_feature_names_out()
# Out:
# array(['13', '1920', '1921', ..., 'zindaginamilegidobara',
#        'zindagiyehzindagi', 'zubeengarg'], dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vectors)

# %%
sorted(list(enumerate(similarity[0])),reverse=True,key=lambda x:x[1])
# Out:
# [(0, 0.9999999999999999),
#  (5, 0.5163977794943223),
#  (34, 0.5163977794943223),
#  (184, 0.5163977794943223),
#  (269, 0.5163977794943223),
#  (371, 0.5163977794943223),
#  (465, 0.5163977794943223),
#  (540, 0.5163977794943223),
#  (587, 0.5163977794943223),
#  (606, 0.5163977794943223),
#  (820, 0.5163977794943223),
#  (919, 0.5163977794943223),
#  (1388, 0.5163977794943223),
#  (1600, 0.5163977794943223),
#  (1931, 0.5163977794943223),
#  (2145, 0.5163977794943223),
#  (2272, 0.5163977794943223),
#  (2358, 0.5163977794943223),
#  (11, 0.4472135954999579),
#  (35, 0.4472135954999579),
#  (40, 0.4472135954999579),
#  (88, 0.4472135954999579),
#  (115, 0.4472135954999579),
#  (117, 0.4472135954999579),
#  (136, 0.4472135954999579),
#  (142, 0.4472135954999579),
#  (241, 0.4472135954999579),
#  (262, 0.4472135954999579),
#  (302, 0.4472135954999579),
#  (309, 0.4472135954999579),
#  (343, 0.4472135954999579),
#  (363, 0.4472135954999579),
#  (375, 0.4472135954999579),
# ...

# %%
df.rename(columns={'Song-Name':'SongName'},inplace=True)
# Out:
# <ipython-input-28-5198bed74ce3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Song-Name':'SongName'},inplace=True)

# %%
def recommend(music):
  music_index=df[df['SongName']==music].index[0]
  distances=similarity[music_index]
  music_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
  for i in music_list:
    print(df.iloc[i[0]].SongName)

# %%
recommend('Coca Cola')
# Out:
# Mile Ho Tum (Reprise)
# La La La (Baazaar)
# Sawan Aaya Hai (Unplugged Version)
# Mohabbat Nasha Hai
# Helicopter

# %%
import pickle
pickle.dump(df,open('musicrec.pkl','wb'))

# %%
pickle.dump(df,open('similarities.pkl','wb'))
